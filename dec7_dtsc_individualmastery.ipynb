# %% [markdown]
# # General information about this assignment
#
# There are five objectives available in this assignment: C1, C7, C8, C9, C10
#
# You may submit for any of these - just one, just two, all five, any combination.
#
# **You may reference course materials for this assignment but you must work on it individually**. You may only ask Dr. B or one of the course TAs for assistance. You should not consult a classmate, friend, family member, pet, acquaintance, enemy, co-worker, etc.

# %% [markdown]
# # C1: Write a solution for a computational problem as pseudocode
#
# 1. In the code block below, set C1 equal to `True` if you are submitting an attempt for this objective.
#     * If you are not submitting an attempt for this objective, you can skip to the other objectives below.
# 1. Enter your solution in the text block that follows.

# %%
C1 = True

# %% [markdown]
# **Scenario for C1:**
# * Suppose your friend becomes an elementary school teacher after they graduate from UNC Charlotte. One afternoon, they have a large stack of student spelling tests to grade. All of the student papers look like this, with names and answers filled in:
# ![](https://thisimpliesthat.com/spellingtest.png)
# * Your friend completes the grading, puts the total number of correct answers in the top right corner of each student's page in a circle, and now it is time to enter the grades into their electronic gradebook.
# * The gradebook stores student records in alphabetical order by last name, and then by first name.
#     * For example, "Juan Ramirez" would be listed somewhere before/above "Juan Zapata", but "Maria Ramirez" would be somewhere in between the two.  (Because Ramirez comes before Zapata alphabetically; Juan comes before Maria alphabetically)
# * **Write pseudocode for an algorithm** that your friend could follow to alphabetize the papers (sort them in the same order as the gradebook records).
#     * Input: A stack of papers that all look like the image shown above.
#         * You may assume all pages have the same orientation. For example: the line that says "Print your first name" is at the "top" of the page, on the side that is face up.
#     * Desired output: A stack of papers with the following properties:
#         * It contains all of the same papers as the input stack (don't lose any or add any new ones)
#         * but those papers have been reordered into alphabetical order as described above
#         * with the beginning of the alphabet at the top of the stack and the end of the alphabet at the bottom of the stack
#         * and the side of each page with the name, answers, and grade should be face-up in the stack.
#
# **Enter your solution below:**
#
# ```
# 1. Identify what is the first letter of the word student printed on  "Print your last name" line
#     2. Place the paper in its correct stack labeled X (X = first letter of last name)
#     If it is the only item then proceed to step 5
#     3. Identify what is the first letter of the word student printed on "Print your first name" line
#     4. Place the paper in the correct order within its last name letter (X group ) by looking at the first paper:
#      If its first letter in  "Print your first name" comes before Y (first letter of first name on the paper) alphabetically then proceed
#      else: Place the paper ahead of the top paper
#     5. Return to step 1 and repeat until there are no graded papers remaining
#     6. You should have twenty six stacks labeled by X, starting with A,then B, C, D, E, F, G, H, I... etc pick up the entire stack and place it on the bottommost of your pile.
#     7. Done.
#
# ```

# %% [markdown]
# # C7: Iterate over a sequence to solve a problem
#
# 1. In the code block below, set C7 equal to `True` if you are submitting an attempt for this objective.
#     * If you are not submitting an attempt for this objective, you can skip to other objectives below.
# 1. In the same code block below where you set the value for `C7`, write code to solve the problem outlined here:
#     * Assume you have a list called `player_goals`
#     * Each element in `player_goals` is a list with two elements. The first element is a string signifying the player's name, and the second element is an integer signifying the number of goals they have scored.
#     * Write Python 3 code, using a loop, to accomplish the following:
#         1. Initialize a new empty list called `all_goals`
#         1. Iterate through each entry in the `player_goals` list and add the number of goals scored by each player into `all_goals`. You should only include the number, not the names.
#     * **Caution:** Your code should work for any valid list called `player_goals` - it should not just be for the examples below.
#
# ## Example 1
# If `player_goals = [["Berardinelli", 3], ["Mayall", 12], ["Mondal", 15], ["Williams", 10]]` then after your code is executed, the value of `all_goals` should be
#     `[3, 12, 15, 10]`
#
# ## Example 2
# (This example is based on the actual leaders in number of goals in the 2023-2024 NHL season as of when this assignment was written.)
#
# Suppose
# ```
# player_goals = [["Boeser", 17],
#                 ["Reinhart", 15],
#                 ["Kucherov", 15],
#                 ["Matthews", 14],
#                 ["Connor", 14],
#                 ["Vatrano", 14],
#                 ["Crosby", 14],
#                 ["Pastrnak", 13],
#                 ["Miller", 13],
#                 ["Kreider", 13]]
# ```
#
# Then after your code is executed, the value of `all_goals` should be
#     `[17, 15, 15, 14, 14, 14, 14, 13, 13, 13]`

# %%
C7 = True

# Enter your code for C7 below
hurricanes_points= [["Aho", 22], 
                  ["Jarvis", 19], 
                  ["Teravainen", 18], 
                  ["Necas", 17], 
                  ["Kotkaniemi", 15],
                  ["Bunting", 15],
                  ["Skjei",15],
                  ["Slavin", 14], 
                  ["Noesen, 13"], 
                  ["Burns", 12],
                  ["Svechnikov", 11],
                  ["Orlov", 9]]
canes_points=[]
for player in hurricanes_points:
    canes_points.append(player[i])

canes_points

# %% [markdown]
# # C8: Compute statistics for a list of data using Python
#
# 1. In the code block below, set C8 equal to `True` if you are submitting an attempt for this objective.
#     * If you are not submitting an attempt for this objective, you can skip to other objectives below.
# 1. In the same code block below where you set the value for `C8`, fill in the lines of code requested, given the scenario outlined here:
#     * Assume you have an already-defined, non-empty list of integer values called `all_goals`
#     * **Example:** Here is one (of many) possible values for the list: `all_goals = [14, 12, 17, 15, 14, 14, 14, 13, 15, 13]`
#     * **Caution:** Your code should work for any valid list called `all_goals` - it should not just be for the example above.

# %%
C8 = True

# Any import statements should go here.
import statistics

# Write the code to find the minimum value of the list and store it in the variable min_goals
min_goals=min('canes_points')

# Write the code to find the maximum value of the list and store it in the variable max_goals
max_goals=max('canes_points')

# Write code to compute the average of the list and store it in the variable goal_average
goal_average=statistics.mean(canes_points)

# Write the code to compute the median of the list and store it in the variable goal_median
goal_median=statistics.median(canes_points)

# %% [markdown]
# # C9: Read/write data from/to a CSV or plaintext file
# # C10: Create visualizations using Python for one or more variables in a dataset
#
#
# ## Problem setup
# This URL contains a dataset with population estimates and age distributions for all 50 states in the US as of 2021: https://thisimpliesthat.com/state_populations.csv
#
# These are the attributes (columns) in the dataset:
# * State - String signifying the name of the state
# * Total population - Total number of people estimated to live in that state in 2021
# * Under 5 years - The percent of the population in that state that was under 5 years old in 2021
# * 5 to 9 years - The percent of the population in that state that was between 5 and 9 years old in 2021
# * There are columns similar to the two above with the following titles:
#     * 10 to 14 years
#     * 15 to 19 years
#     * 20 to 24 years
#     * 25 to 29 years
#     * 30 to 34 years
#     * 35 to 39 years
#     * 40 to 44 years
#     * 45 to 49 years
#     * 50 to 54 years
#     * 55 to 59 years
#     * 60 to 64 years
#     * 65 to 69 years
#     * 70 to 74 years
#     * 75 to 79 years
#     * 80 to 84 years
#     * 85 years and over
# * Median age (years) - A decimal number indicating the median age of the total population in that state in 2021
#
# ## Problem instructions
# In the code block below, write code that:
# 1. Loads the dataset.
# 1. Generates a scatterplot where each dot represents one state, the x-coordinate of each dot is the total population of the state, and the y-coordinate of each dot is the median age of the population in each state.
# 1. Adds an accurate title/label for each axis. (But you do not need to change the values shown on the x- or y-axis, also known as the "xticks" and "yticks".)

# %%
# Write your code for C9/C10 here

import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("state_populations.csv")
print(df.head(10))
sns.scatterplot(data=df, x="Total population", y="Median age (years)").set(title="Total State Population versus Median Age")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7d1519ff-6c32-40f3-9aa0-ce9947006898' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
